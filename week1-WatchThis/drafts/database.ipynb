# %%
import psycopg2
from psycopg2.extensions import ISOLATION_LEVEL_AUTOCOMMIT
from pgvector.psycopg2 import register_vector
import pandas as pd

# %%
DB_NAME = "***"
USER = "**"
PASSWORD = "***"
HOST = "localhost"
PORT = "5432"

# %%
conn = psycopg2.connect(dbname="***", user=USER, password=PASSWORD, host=HOST, port=PORT)
conn.set_isolation_level(ISOLATION_LEVEL_AUTOCOMMIT)
cur = conn.cursor()

# %%
# Create database if it does not exist
cur.execute(f"SELECT 1 FROM pg_database WHERE datname = '{DB_NAME}';")
exists = cur.fetchone()

# %%
if not exists:
    cur.execute(f"CREATE DATABASE {DB_NAME};")
    print(f"Database '{DB_NAME}' created.")
else:
    print(f"Database '{DB_NAME}' already exists.")
# Out:
# Database 'Nitec' already exists.

# %%
cur.close()
conn.close()

# %%
conn = psycopg2.connect(dbname=DB_NAME, user=USER, password=PASSWORD, host=HOST, port=PORT)
cur = conn.cursor()

# %%
cur.execute("CREATE EXTENSION IF NOT EXISTS vector;")
conn.commit()

# %%
register_vector(conn)

print("Connected to database and pgvector extension is set up!")
# Out:
# Connected to database and pgvector extension is set up!

# %%
cur.execute("""
    CREATE TABLE IF NOT EXISTS movies (
        id SERIAL PRIMARY KEY,
        title TEXT,
        plot TEXT,
        genres TEXT,
        movie_cast TEXT,
        fullplot TEXT,
        countries TEXT,
        directors TEXT,
        rated TEXT,
        lastupdated TEXT,
        type TEXT,
        runtime TEXT,
        released BIGINT,
        awards_wins INT,
        awards_nominations INT,
        year INT,
        poster TEXT,
        languages TEXT,
        writers TEXT,
        merged_rating TEXT,
        merged_plot TEXT,
        embeddings VECTOR(384)
    );
""")
conn.commit()
print("Table 'movies' created successfully!")
# Out:
# Table 'movies' created successfully!

# %%
# conn.rollback()

# %%
df=pd.read_parquet('./processed_mflix_movies_embedded.parquet')
len(df['embeddings'][0])
# Out:
# 384

# %%
insert_query = """
    INSERT INTO movies (title, plot, genres, movie_cast, fullplot, countries, 
                        directors, rated, lastupdated, type, runtime, released, 
                        awards_wins, awards_nominations, year, poster, languages, 
                        writers, merged_rating, merged_plot, embeddings)
    VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s);
"""

# %%
df.fillna({
    "runtime.$numberInt": 0,
    "released.$date.$numberLong": 0,
    "awards.wins.$numberInt": 0,
    "awards.nominations.$numberInt": 0,
    "year.$numberInt": 0
}, inplace=True)

# %%
df
# Out:
#                                                     plot  \
# 0      Three men hammer on an anvil and pass a bottle...
# 1      A group of bandits stage a brazen train hold-u...
# 2      A young boy, opressed by his mother, goes on a...
# 3      A greedy tycoon decides, on a whim, to corner ...
# 4      Cartoon figures announce, via comic strip ball...
# ...                                                  ...
# 23442                                               None
# 23443                                               None
# 23444                                               None
# 23445                                               None
# 23446                                               None
#
#                            genres  \
# 0                         [Short]
# 1                [Short, Western]
# 2         [Short, Drama, Fantasy]
# 3                  [Short, Drama]
# 4      [Animation, Short, Comedy]
# ...                           ...
# 23442                        None
# 23443                        None
# 23444                        None
# 23445                        None
# 23446                        None
#
#                                                     cast  \
# 0                             [Charles Kayser, John Ott]
# 1      [A.C. Abadie, Gilbert M. 'Broncho Billy' Ander...
# 2      [Martin Fuller, Mrs. William Bechtel, Walter E...
# 3      [Frank Powell, Grace Henderson, James Kirkwood...
# 4                                         [Winsor McCay]
# ...                                                  ...
# 23442                                               None
# 23443                                               None
# 23444                                               None
# 23445                                               None
# 23446                                               None
#
#                                                    title  \
# 0                                       Blacksmith Scene
# 1                                The Great Train Robbery
# 2                             The Land Beyond the Sunset
# 3                                      A Corner in Wheat
# 4      Winsor McCay, the Famous Cartoonist of the N.Y...
# ...                                                  ...
# 23442                                               None
# 23443                                               None
# 23444                                               None
# 23445                                               None
# 23446                                               None
#
#                                                 fullplot countries  \
# 0      A stationary camera looks at a large anvil wit...     [USA]
# 1      Among the earliest existing films in American ...     [USA]
# 2      Thanks to the Fresh Air Fund, a slum child esc...     [USA]
# 3      A greedy tycoon decides, on a whim, to corner ...     [USA]
# 4      Cartoonist Winsor McCay agrees to create a lar...     [USA]
# ...                                                  ...       ...
# 23442                                               None      None
# 23443                                               None      None
# 23444                                               None      None
# 23445                                               None      None
# 23446                                               None      None
#
#                                 directors    rated  \
# 0                  [William K.L. Dickson]  UNRATED
# 1                       [Edwin S. Porter]     TV-G
# 2                        [Harold M. Shaw]  UNRATED
# 3                         [D.W. Griffith]        G
# 4      [Winsor McCay, J. Stuart Blackton]     None
# ...                                   ...      ...
# 23442                                None     None
# 23443                                None     None
# 23444                                None     None
# 23445                                None     None
# 23446                                None     None
#
#                          lastupdated   type  ... released.$date.$numberLong  \
# 0      2015-08-26 00:03:50.133000000  movie  ...             -2418768000000
# 1      2015-08-13 00:27:59.177000000  movie  ...             -2085523200000
# 2      2015-08-29 00:27:45.437000000  movie  ...             -1804377600000
# 3      2015-08-13 00:46:30.660000000  movie  ...             -1895097600000
# 4      2015-08-29 01:09:03.030000000  movie  ...             -1853539200000
# ...                              ...    ...  ...                        ...
# 23442                           None   None  ...                          0
# 23443                           None   None  ...                          0
# 23444                           None   None  ...                          0
# 23445                           None   None  ...                          0
# 23446                           None   None  ...                          0
#
#       awards.wins.$numberInt awards.nominations.$numberInt year.$numberInt  \
# 0                          1                             0            1893
# 1                          1                             0            1903
# 2                          1                             0            1912
# 3                          1                             0            1909
# 4                          1                             0            1911
# ...                      ...                           ...             ...
# 23442                      0                             0               0
# 23443                      0                             0               0
# 23444                      0                             0               0
# 23445                      0                             0               0
# 23446                      0                             0               0
#
#                                                   poster  languages  \
# 0                                                   None       None
# 1      https://m.media-amazon.com/images/M/MV5BMTU3Nj...  [English]
# 2      https://m.media-amazon.com/images/M/MV5BMTMzMD...  [English]
# 3                                                   None  [English]
# 4      https://m.media-amazon.com/images/M/MV5BYzg2Nj...  [English]
# ...                                                  ...        ...
# 23442                                               None       None
# 23443                                               None       None
# 23444                                               None       None
# 23445                                               None       None
# 23446                                               None       None
#
#                                                  writers merged_rating  \
# 0                                                   None           6.2
# 1                                                   None           7.4
# 2                                     [Dorothy G. Shore]           7.1
# 3                                                   None           6.6
# 4      [Winsor McCay (comic strip "Little Nemo in Slu...           7.3
# ...                                                  ...           ...
# 23442                                               None          None
# 23443                                               None          None
# 23444                                               None          None
# 23445                                               None          None
# 23446                                               None          None
#
#                                              merged_plot  \
# 0      A stationary camera looks at a large anvil wit...
# 1      Among the earliest existing films in American ...
# 2      Thanks to the Fresh Air Fund, a slum child esc...
# 3      A greedy tycoon decides, on a whim, to corner ...
# 4      Cartoonist Winsor McCay agrees to create a lar...
# ...                                                  ...
# 23442                                               None
# 23443                                               None
# 23444                                               None
# 23445                                               None
# 23446                                               None
#
#                                               embeddings
# 0      [-0.06101669743657112, 0.0607670433819294, -0....
# 1      [-0.05368781089782715, -0.01406814344227314, -...
# 2      [0.02496330812573433, 0.06163919344544411, -4....
# 3      [-0.05462929233908653, 0.0717046782374382, -0....
# 4      [-0.04025116562843323, -0.046722412109375, -0....
# ...                                                  ...
# 23442                                                 []
# 23443                                                 []
# 23444                                                 []
# 23445                                                 []
# 23446                                                 []
#
# [23447 rows x 21 columns]

# %%
df.isna().sum()
# Out:
# plot                             1074
# genres                           1147
# cast                             1402
# title                            1074
# fullplot                         1450
# countries                        1084
# directors                        1329
# rated                            9866
# lastupdated                      1074
# type                             1074
# runtime.$numberInt                  0
# released.$date.$numberLong          0
# awards.wins.$numberInt              0
# awards.nominations.$numberInt       0
# year.$numberInt                     0
# poster                           3645
# languages                        1297
# writers                          2245
# merged_rating                    1607
# merged_plot                      1074
# embeddings                          0
# dtype: int64

# %%
df.fillna('-', inplace=True)

# %%
data = [
    (
        row["title"], row["plot"], row["genres"], row["cast"], row["fullplot"],
        row["countries"], row["directors"], row["rated"], row["lastupdated"],
        row["type"], row["runtime.$numberInt"], int(row["released.$date.$numberLong"]),
        int(row["awards.wins.$numberInt"]), int(row["awards.nominations.$numberInt"]),
        int(row["year.$numberInt"]), row["poster"], row["languages"], row["writers"],
        row["merged_rating"], row["merged_plot"], row["embeddings"]
    )
    for _, row in df.iterrows()
]

# %%
import ast
import numpy as np

def convert_embedding(embedding):
    if isinstance(embedding, str):
        try:
            return np.array(ast.literal_eval(embedding), dtype=np.float32)
        except Exception as e:
            print(f"Error converting string embedding: {embedding} -> {e}")
            return np.zeros(384, dtype=np.float32)
    elif isinstance(embedding, (list, np.ndarray)):
        try:
            return np.array(embedding, dtype=np.float32)
        except Exception as e:
            print(f"Error converting list/ndarray embedding: {embedding} -> {e}")
            return np.zeros(384, dtype=np.float32)
    else:
        print(f"Invalid embedding type: {type(embedding)}")
        return np.zeros(384, dtype=np.float32)

df["embeddings"] = df["embeddings"].apply(convert_embedding)

# %%
invalid_embeddings = df[df['embeddings'].apply(lambda x: not isinstance(x, (np.ndarray, list)))]
print(invalid_embeddings[['title', 'embeddings']])
# Out:
# Empty DataFrame
# Columns: [title, embeddings]
# Index: []

# %%
# df.iloc[21299:]

# %%
for i, row in df.iterrows():
    try:
        data = (
            row["title"], row["plot"], row["genres"], row["cast"], row["fullplot"],
            row["countries"], row["directors"], row["rated"], row["lastupdated"],
            row["type"], row["runtime.$numberInt"], int(row["released.$date.$numberLong"]),
            int(row["awards.wins.$numberInt"]), int(row["awards.nominations.$numberInt"]),
            int(row["year.$numberInt"]), row["poster"], row["languages"], row["writers"],
            row["merged_rating"], row["merged_plot"], row["embeddings"]
        )
        cur.execute(insert_query, data)
    except Exception as e:
        print(f"Error inserting row {i} (Title: {row['title']}): {e}")
        continue  # Skip to next row

conn.commit()
print("Data inserted successfully!")
# Out:
# Error inserting row 0 (Title: Blacksmith Scene): could not convert string to float: 'Short'
# Error inserting row 1 (Title: The Great Train Robbery): could not convert string to float: 'Short'
# Error inserting row 2 (Title: The Land Beyond the Sunset): could not convert string to float: 'Short'
# Error inserting row 3 (Title: A Corner in Wheat): could not convert string to float: 'Short'
# Error inserting row 4 (Title: Winsor McCay, the Famous Cartoonist of the N.Y. Herald and His Moving Comics): could not convert string to float: 'Animation'
# Error inserting row 5 (Title: Traffic in Souls): could not convert string to float: 'Crime'
# Error inserting row 6 (Title: Gertie the Dinosaur): could not convert string to float: 'Animation'
# Error inserting row 7 (Title: In the Land of the Head Hunters): could not convert string to float: 'Drama'
# Error inserting row 8 (Title: The Perils of Pauline): could not convert string to float: 'Action'
# Error inserting row 9 (Title: The Birth of a Nation): could not convert string to float: 'Drama'
# Error inserting row 10 (Title: The Cheat): could not convert string to float: 'Drama'
# Error inserting row 11 (Title: The Italian): could not convert string to float: 'Drama'
# Error inserting row 12 (Title: Regeneration): could not convert string to float: 'Biography'
# Error inserting row 13 (Title: Les vampires): could not convert string to float: 'Action'
# Error inserting row 14 (Title: Civilization): could not convert string to float: 'Drama'
# Error inserting row 15 (Title: Hell's Hinges): could not convert string to float: 'Romance'
# Error inserting row 16 (Title: Intolerance: Love's Struggle Throughout the Ages): could not convert string to float: 'Drama'
# Error inserting row 17 (Title: Where Are My Children?): could not convert string to float: 'Drama'
# Error inserting row 18 (Title: The Immigrant): could not convert string to float: 'Short'
# Error inserting row 19 (Title: The Poor Little Rich Girl): could not convert string to float: 'Comedy'
# Error inserting row 20 (Title: Wild and Woolly): could not convert string to float: 'Comedy'
# Error inserting row 21 (Title: The Blue Bird): could not convert string to float: 'Fantasy'
# Error inserting row 22 (Title: Broken Blossoms or The Yellow Man and the Girl): could not convert string to float: 'Drama'
# Error inserting row 23 (Title: From Hand to Mouth): could not convert string to float: 'Comedy'
# Error inserting row 24 (Title: High and Dizzy): could not convert string to float: 'Comedy'
# Error inserting row 25 (Title: The Last of the Mohicans): could not convert string to float: 'Adventure'
# Error inserting row 26 (Title: One Week): could not convert string to float: 'Short'
# Error inserting row 27 (Title: The Saphead): could not convert string to float: 'Comedy'
# Error inserting row 28 (Title: Within Our Gates): could not convert string to float: 'Drama'
# Error inserting row 29 (Title: The Ace of Hearts): could not convert string to float: 'Crime'
# Error inserting row 30 (Title: The Four Horsemen of the Apocalypse): could not convert string to float: 'Drama'
# Error inserting row 31 (Title: The Kid): could not convert string to float: 'Comedy'
# Error inserting row 32 (Title: Miss Lulu Bett): could not convert string to float: 'Comedy'
# Error inserting row 33 (Title: Now or Never): could not convert string to float: 'Comedy'
# Error inserting row 34 (Title: Tol'able David): could not convert string to float: 'Drama'
# Error inserting row 35 (Title: Cops): could not convert string to float: 'Short'
# Error inserting row 36 (Title: Foolish Wives): could not convert string to float: 'Drama'
# Error inserting row 37 (Title: Nanook of the North): could not convert string to float: 'Documentary'
# Error inserting row 38 (Title: Nosferatu): could not convert string to float: 'Horror'
# Error inserting row 39 (Title: Salomè): could not convert string to float: 'Biography'
# Error inserting row 40 (Title: Robin Hood): could not convert string to float: 'Adventure'
# Error inserting row 41 (Title: The Hunchback of Notre Dame): could not convert string to float: 'Drama'
# Error inserting row 42 (Title: Our Hospitality): could not convert string to float: 'Comedy'
# Error inserting row 43 (Title: Safety Last!): could not convert string to float: 'Comedy'
# Error inserting row 44 (Title: Three Ages): could not convert string to float: 'Comedy'
# Error inserting row 45 (Title: A Woman of Paris: A Drama of Fate): could not convert string to float: 'Drama'
# Error inserting row 46 (Title: The Chechahcos): could not convert string to float: 'Adventure'
# Error inserting row 47 (Title: He Who Gets Slapped): could not convert string to float: 'Drama'
# Error inserting row 48 (Title: The Iron Horse): could not convert string to float: 'Western'
# Error inserting row 49 (Title: The Navigator): could not convert string to float: 'Action'
# Error inserting row 50 (Title: Peter Pan): could not convert string to float: 'Adventure'
# Error inserting row 51 (Title: Sherlock Jr.): could not convert string to float: 'Comedy'
# Error inserting row 52 (Title: The Thief of Bagdad): could not convert string to float: 'Adventure'
# Error inserting row 53 (Title: Wild Oranges): could not convert string to float: 'Drama'
# Error inserting row 54 (Title: White Shadows): could not convert string to float: 'Drama'
# Error inserting row 55 (Title: The Big Parade): could not convert string to float: 'Drama'
# Error inserting row 56 (Title: Battleship Potemkin): could not convert string to float: 'History'
# Error inserting row 57 (Title: Clash of the Wolves): could not convert string to float: 'Adventure'
# Error inserting row 58 (Title: The Freshman): could not convert string to float: 'Comedy'
# Error inserting row 59 (Title: Go West): could not convert string to float: 'Comedy'
# Error inserting row 60 (Title: Grass: A Nation's Battle for Life): could not convert string to float: 'Documentary'
# Error inserting row 61 (Title: Greed): could not convert string to float: 'Drama'
# Error inserting row 62 (Title: The Gold Rush): could not convert string to float: 'Adventure'
# Error inserting row 63 (Title: Lady Windermere's Fan): could not convert string to float: 'Comedy'
# Error inserting row 64 (Title: The Lost World): could not convert string to float: 'Adventure'
# Error inserting row 65 (Title: The Phantom of the Opera): could not convert string to float: 'Horror'
# Error inserting row 66 (Title: Seven Chances): could not convert string to float: 'Comedy'
# Error inserting row 67 (Title: Beau Geste): could not convert string to float: 'Action'
# Error inserting row 68 (Title: Battling Butler): could not convert string to float: 'Comedy'
# Error inserting row 69 (Title: Ben-Hur: A Tale of the Christ): could not convert string to float: 'Adventure'
# Error inserting row 70 (Title: The Black Pirate): could not convert string to float: 'Adventure'
# Error inserting row 71 (Title: Ella Cinders): could not convert string to float: 'Comedy'
# Error inserting row 72 (Title: Flesh and the Devil): could not convert string to float: 'Drama'
# Error inserting row 73 (Title: For Heaven's Sake): could not convert string to float: 'Action'
# Error inserting row 74 (Title: Metropolis): could not convert string to float: 'Drama'
# Error inserting row 75 (Title: The Son of the Sheik): could not convert string to float: 'Adventure'
# Error inserting row 76 (Title: The Strong Man): could not convert string to float: 'Comedy'
# Error inserting row 77 (Title: College): could not convert string to float: 'Comedy'
# Error inserting row 78 (Title: The General): could not convert string to float: 'Action'
# Error inserting row 79 (Title: It): could not convert string to float: 'Comedy'
# Error inserting row 80 (Title: The Jazz Singer): could not convert string to float: 'Drama'
# Error inserting row 81 (Title: The Kid Brother): could not convert string to float: 'Comedy'
# Error inserting row 82 (Title: Napoleon): could not convert string to float: 'Biography'
# Error inserting row 83 (Title: 7th Heaven): could not convert string to float: 'Drama'
# Error inserting row 84 (Title: Sunrise): could not convert string to float: 'Drama'
# Error inserting row 85 (Title: The Unknown): could not convert string to float: 'Drama'
# Error inserting row 86 (Title: Upstream): could not convert string to float: 'Comedy'
# Error inserting row 87 (Title: Wings): could not convert string to float: 'Drama'
# Error inserting row 88 (Title: The Cameraman): could not convert string to float: 'Comedy'
# Error inserting row 89 (Title: Pandora's Box): could not convert string to float: 'Crime'
# Error inserting row 90 (Title: The Circus): could not convert string to float: 'Comedy'
# Error inserting row 91 (Title: The Crowd): could not convert string to float: 'Drama'
# Error inserting row 92 (Title: The Docks of New York): could not convert string to float: 'Crime'
# Error inserting row 93 (Title: The Fall of the House of Usher): could not convert string to float: 'Short'
# Error inserting row 94 (Title: Four Sons): could not convert string to float: 'Drama'
# Error inserting row 95 (Title: The Last Command): could not convert string to float: 'Drama'
# Error inserting row 96 (Title: Laugh, Clown, Laugh): could not convert string to float: 'Drama'
# Error inserting row 97 (Title: Lonesome): could not convert string to float: 'Comedy'
# Error inserting row 98 (Title: The Passion of Joan of Arc): could not convert string to float: 'Biography'
# Error inserting row 99 (Title: Storm Over Asia): could not convert string to float: 'Drama'
# Error inserting row 100 (Title: Show People): could not convert string to float: 'Comedy'
# Error inserting row 101 (Title: Steamboat Bill, Jr.): could not convert string to float: 'Action'
# Error inserting row 102 (Title: Street Angel): could not convert string to float: 'Drama'
# Error inserting row 103 (Title: Steamboat Willie): could not convert string to float: 'Animation'
# Error inserting row 104 (Title: The Wedding March): could not convert string to float: 'Drama'
# Error inserting row 105 (Title: The Wind): could not convert string to float: 'Drama'
# Error inserting row 106 (Title: Applause): could not convert string to float: 'Drama'
# Error inserting row 107 (Title: Asphalt): could not convert string to float: 'Drama'
# Error inserting row 108 (Title: The Broadway Melody): could not convert string to float: 'Musical'
# Error inserting row 109 (Title: Man with a Movie Camera): could not convert string to float: 'Documentary'
# Error inserting row 110 (Title: Disraeli): could not convert string to float: 'Biography'
# Error inserting row 111 (Title: The Divine Lady): could not convert string to float: 'Drama'
# Error inserting row 112 (Title: Hallelujah): could not convert string to float: 'Drama'
# Error inserting row 113 (Title: In Old Arizona): could not convert string to float: 'Romance'
# Error inserting row 114 (Title: Queen Kelly): could not convert string to float: 'Drama'
# Error inserting row 115 (Title: All Quiet on the Western Front): could not convert string to float: 'Drama'
# Error inserting row 116 (Title: The Big House): could not convert string to float: 'Drama'
# Error inserting row 117 (Title: The Big Trail): could not convert string to float: 'Adventure'
# Error inserting row 118 (Title: The Divorcee): could not convert string to float: 'Romance'
# Error inserting row 119 (Title: The Devil to Pay!): could not convert string to float: 'Comedy'
# Error inserting row 120 (Title: King of Jazz): could not convert string to float: 'Animation'
# Error inserting row 121 (Title: Little Caesar): could not convert string to float: 'Crime'
# Error inserting row 122 (Title: Men Without Women): could not convert string to float: 'Action'
# Error inserting row 123 (Title: Morocco): could not convert string to float: 'Romance'
# Error inserting row 124 (Title: Romance): could not convert string to float: 'Drama'
# Error inserting row 125 (Title: The Blood of a Poet): could not convert string to float: 'Enrique Rivero'
# Error inserting row 126 (Title: Under the Roofs of Paris): could not convert string to float: 'Comedy'
# Error inserting row 127 (Title: Westfront 1918): could not convert string to float: 'Drama'
# Error inserting row 128 (Title: Earth): could not convert string to float: 'Drama'
# Error inserting row 129 (Title: Nosferatu): could not convert string to float: 'Horror'
# Error inserting row 130 (Title: Bad Girl): could not convert string to float: 'Drama'
# Error inserting row 131 (Title: The Champ): could not convert string to float: 'Drama'
# Error inserting row 132 (Title: Cimarron): could not convert string to float: 'Drama'
# Error inserting row 133 (Title: City Streets): could not convert string to float: 'Crime'
# Error inserting row 134 (Title: City Lights): could not convert string to float: 'Comedy'
# Error inserting row 135 (Title: Dishonored): could not convert string to float: 'Drama'
# Error inserting row 136 (Title: Dracula): could not convert string to float: 'Horror'
# Error inserting row 137 (Title: The 3 Penny Opera): could not convert string to float: 'Comedy'
# Error inserting row 138 (Title: Frankenstein): could not convert string to float: 'Horror'
# Error inserting row 139 (Title: A Free Soul): could not convert string to float: 'Crime'
# Error inserting row 140 (Title: The Guardsman): could not convert string to float: 'Comedy'
# Error inserting row 141 (Title: The Front Page): could not convert string to float: 'Comedy'
# Error inserting row 142 (Title: Comradeship): could not convert string to float: 'Drama'
# Error inserting row 143 (Title: M): could not convert string to float: 'Crime'
# Error inserting row 144 (Title: Mèdchen in Uniform): could not convert string to float: 'Drama'
# Error inserting row 145 (Title: The Public Enemy): could not convert string to float: 'Crime'
# Error inserting row 146 (Title: The Sin of Madelon Claudet): could not convert string to float: 'Drama'
# Error inserting row 147 (Title: Skippy): could not convert string to float: 'Family'
# Error inserting row 148 (Title: Tabu: A Story of the South Seas): could not convert string to float: 'Drama'
# Error inserting row 149 (Title: è Nous la Libertè): could not convert string to float: 'Comedy'
# Error inserting row 150 (Title: The Blue Light): could not convert string to float: 'Drama'
# Error inserting row 151 (Title: Broken Lullaby): could not convert string to float: 'Drama'
# Error inserting row 152 (Title: The Crowd Roars): could not convert string to float: 'Drama'
# Error inserting row 153 (Title: Dr. Jekyll and Mr. Hyde): could not convert string to float: 'Horror'
# Error inserting row 154 (Title: A Farewell to Arms): could not convert string to float: 'Drama'
# Error inserting row 155 (Title: Forbidden): could not convert string to float: 'Drama'
# Error inserting row 156 (Title: Freaks): could not convert string to float: 'Drama'
# Error inserting row 157 (Title: Grand Hotel): could not convert string to float: 'Drama'
# Error inserting row 158 (Title: I Am a Fugitive from a Chain Gang): could not convert string to float: 'Crime'
# Error inserting row 159 (Title: Love Me Tonight): could not convert string to float: 'Comedy'
# Error inserting row 160 (Title: Murders in the Rue Morgue): could not convert string to float: 'Crime'
# Error inserting row 161 (Title: The Mummy): could not convert string to float: 'Horror'
# Error inserting row 162 (Title: Movie Crazy): could not convert string to float: 'Comedy'
# Error inserting row 163 (Title: The Music Box): could not convert string to float: 'Comedy'
# Error inserting row 164 (Title: Payment Deferred): could not convert string to float: 'Crime'
# Error inserting row 165 (Title: Red Dust): could not convert string to float: 'Drama'
# Error inserting row 166 (Title: Scarface): could not convert string to float: 'Action'
# Error inserting row 167 (Title: Shanghai Express): could not convert string to float: 'Adventure'
# Error inserting row 168 (Title: Smilin' Through): could not convert string to float: 'Drama'
# Error inserting row 169 (Title: Tarzan the Ape Man): could not convert string to float: 'Action'
# Error inserting row 170 (Title: Two Seconds): could not convert string to float: 'Drama'
# Error inserting row 171 (Title: Trouble in Paradise): could not convert string to float: 'Comedy'
# Error inserting row 172 (Title: I Was Born, But...): could not convert string to float: 'Comedy'
# Error inserting row 173 (Title: Baby Face): could not convert string to float: 'Drama'
# Error inserting row 174 (Title: Berkeley Square): could not convert string to float: 'Fantasy'
# Error inserting row 175 (Title: Cavalcade): could not convert string to float: 'Drama'
# Error inserting row 176 (Title: Dekigokoro): could not convert string to float: 'Drama'
# Error inserting row 177 (Title: Duck Soup): could not convert string to float: 'Comedy'
# Error inserting row 178 (Title: Eskimo): could not convert string to float: 'Drama'
# Error inserting row 179 (Title: Footlight Parade): could not convert string to float: 'Comedy'
# Error inserting row 180 (Title: 42nd Street): could not convert string to float: 'Comedy'
# Error inserting row 181 (Title: Flying Down to Rio): could not convert string to float: 'Comedy'
# Error inserting row 182 (Title: The Emperor Jones): could not convert string to float: 'Drama'
# Error inserting row 183 (Title: Gold Diggers of 1933): could not convert string to float: 'Comedy'
# Error inserting row 184 (Title: Going Hollywood): could not convert string to float: 'Musical'
# Error inserting row 185 (Title: The Invisible Man): could not convert string to float: 'Drama'
# Error inserting row 186 (Title: King Kong): could not convert string to float: 'Adventure'
# Error inserting row 187 (Title: Little Women): could not convert string to float: 'Drama'
# Error inserting row 188 (Title: The Power and the Glory): could not convert string to float: 'Drama'
# Error inserting row 189 (Title: The Private Life of Henry VIII.): could not convert string to float: 'Biography'
# Error inserting row 190 (Title: Queen Christina): could not convert string to float: 'Biography'
# Error inserting row 191 (Title: She Done Him Wrong): could not convert string to float: 'Comedy'
# Error inserting row 192 (Title: Sons of the Desert): could not convert string to float: 'Comedy'
# Error inserting row 193 (Title: The Son of Kong): could not convert string to float: 'Adventure'
# Error inserting row 194 (Title: State Fair): could not convert string to float: 'Comedy'
# Error inserting row 195 (Title: Three Little Pigs): could not convert string to float: 'Animation'
# Error inserting row 196 (Title: Topaze): could not convert string to float: 'Drama'
# Error inserting row 197 (Title: Wild Boys of the Road): could not convert string to float: 'Adventure'
# Error inserting row 198 (Title: Zoo in Budapest): could not convert string to float: 'Drama'
# Error inserting row 199 (Title: Zero for Conduct): could not convert string to float: 'Short'
# Error inserting row 200 (Title: The Barretts of Wimpole Street): could not convert string to float: 'Biography'
# Error inserting row 201 (Title: The Black Cat): could not convert string to float: 'Horror'
# Error inserting row 202 (Title: Broadway Bill): could not convert string to float: 'Comedy'
# Error inserting row 203 (Title: Chapayev): could not convert string to float: 'Comedy'
# Error inserting row 204 (Title: Cleopatra): could not convert string to float: 'Biography'
# Error inserting row 205 (Title: The Count of Monte Cristo): could not convert string to float: 'Action'
# Error inserting row 206 (Title: Death Takes a Holiday): could not convert string to float: 'Drama'
# Error inserting row 207 (Title: Dames): could not convert string to float: 'Comedy'
# Error inserting row 208 (Title: The Gay Divorcee): could not convert string to float: 'Comedy'
# Error inserting row 209 (Title: Le grand jeu): could not convert string to float: 'Drama'
# Error inserting row 210 (Title: Imitation of Life): could not convert string to float: 'Drama'
# Error inserting row 211 (Title: It Happened One Night): could not convert string to float: 'Comedy'
# Error inserting row 212 (Title: It's a Gift): could not convert string to float: 'Comedy'
# Error inserting row 213 (Title: Little Miss Marker): could not convert string to float: 'Comedy'
# Error inserting row 214 (Title: The Lost Patrol): could not convert string to float: 'Adventure'
# Error inserting row 215 (Title: Man of Aran): could not convert string to float: 'Documentary'
# Error inserting row 216 (Title: Maria Chapdelaine): could not convert string to float: 'Drama'
# Error inserting row 217 (Title: The Man Who Knew Too Much): could not convert string to float: 'Crime'
# Error inserting row 218 (Title: Les Misèrables): could not convert string to float: 'Drama'
# Error inserting row 219 (Title: Masquerade in Vienna): could not convert string to float: 'Comedy'
# Error inserting row 220 (Title: One Night of Love): could not convert string to float: 'Music'
# Error inserting row 221 (Title: The Private Life of Don Juan): could not convert string to float: 'Comedy'
# Error inserting row 222 (Title: The Scarlet Empress): could not convert string to float: 'Drama'
# Error inserting row 223 (Title: Everybody's Woman): could not convert string to float: 'Drama'
# Error inserting row 224 (Title: Tarzan and His Mate): could not convert string to float: 'Action'
# Error inserting row 225 (Title: The Thin Man): could not convert string to float: 'Comedy'
# Error inserting row 226 (Title: Toni): could not convert string to float: 'Drama'
# Error inserting row 227 (Title: Triumph of the Will): could not convert string to float: 'Documentary'
# Error inserting row 228 (Title: A Story of Floating Weeds): could not convert string to float: 'Drama'
# Error inserting row 229 (Title: Twentieth Century): could not convert string to float: 'Comedy'
# Error inserting row 230 (Title: Moscow Laughs): could not convert string to float: 'Comedy'
# Error inserting row 231 (Title: Viva Villa!): could not convert string to float: 'Biography'
# Error inserting row 232 (Title: The 39 Steps): could not convert string to float: 'Mystery'
# Error inserting row 233 (Title: Wonder Bar): could not convert string to float: 'Crime'
# Error inserting row 234 (Title: Anna Karenina): could not convert string to float: 'Drama'
# Error inserting row 235 (Title: The Band Concert): could not convert string to float: 'Family'
# Error inserting row 236 (Title: Becky Sharp): could not convert string to float: 'Drama'
# Error inserting row 237 (Title: Alice Adams): could not convert string to float: 'Comedy'
# Error inserting row 238 (Title: Black Fury): could not convert string to float: 'Crime'
# Error inserting row 239 (Title: Bride of Frankenstein): could not convert string to float: 'Horror'
# Error inserting row 240 (Title: Broadway Melody of 1936): could not convert string to float: 'Musical'
# Error inserting row 241 (Title: China Seas): could not convert string to float: 'Action'
# Error inserting row 242 (Title: Curly Top): could not convert string to float: 'Family'
# Error inserting row 243 (Title: Dante's Inferno): could not convert string to float: 'Drama'
# Error inserting row 244 (Title: The Crusades): could not convert string to float: 'Adventure'
# Error inserting row 245 (Title: David Copperfield): could not convert string to float: 'Adventure'
# Error inserting row 246 (Title: The Dark Angel): could not convert string to float: 'Drama'
# Error inserting row 247 (Title: The Devil Is a Woman): could not convert string to float: 'Comedy'
# Error inserting row 248 (Title: Folies Bergère de Paris): could not convert string to float: 'Comedy'
# Error inserting row 249 (Title: The Gilded Lily): could not convert string to float: 'Comedy'
# Error inserting row 250 (Title: The Ghost Goes West): could not convert string to float: 'Comedy'
# Error inserting row 251 (Title: Gold Diggers of 1935): could not convert string to float: 'Comedy'
# Error inserting row 252 (Title: The Informer): could not convert string to float: 'Drama'
# Error inserting row 253 (Title: Carnival in Flanders): could not convert string to float: 'Comedy'
# Error inserting row 254 (Title: The Lives of a Bengal Lancer): could not convert string to float: 'Adventure'
# Error inserting row 255 (Title: A Midsummer Night's Dream): could not convert string to float: 'Comedy'
# Error inserting row 256 (Title: Les Misèrables): could not convert string to float: 'Drama'
# Error inserting row 257 (Title: Mutiny on the Bounty): could not convert string to float: 'Adventure'
# Error inserting row 258 (Title: Naughty Marietta): could not convert string to float: 'Drama'
# Error inserting row 259 (Title: A Night at the Opera): could not convert string to float: 'Comedy'
# Error inserting row 260 (Title: The New Gulliver): could not convert string to float: 'Animation'
# Error inserting row 261 (Title: Roberta): could not convert string to float: 'Comedy'
# Error inserting row 262 (Title: Ruggles of Red Gap): could not convert string to float: 'Comedy'
# Error inserting row 263 (Title: Sanders of the River): could not convert string to float: 'Adventure'
# Error inserting row 264 (Title: Scrooge): could not convert string to float: 'Drama'
# Error inserting row 265 (Title: She): could not convert string to float: 'Adventure'
# Error inserting row 266 (Title: Swedenhielms Family): could not convert string to float: 'Comedy'
# Error inserting row 267 (Title: Top Hat): could not convert string to float: 'Comedy'
# Error inserting row 268 (Title: Wife! Be Like a Rose!): could not convert string to float: 'Drama'
# Error inserting row 269 (Title: The Wedding Night): could not convert string to float: 'Drama'
# Error inserting row 270 (Title: Who Killed Cock Robin?): could not convert string to float: 'Animation'
# Error inserting row 271 (Title: Anthony Adverse): could not convert string to float: 'Adventure'
# Error inserting row 272 (Title: The Lower Depths): could not convert string to float: 'Crime'
# Error inserting row 273 (Title: Black Legion): could not convert string to float: 'Crime'
# Error inserting row 274 (Title: The Charge of the Light Brigade): could not convert string to float: 'Action'
# Error inserting row 275 (Title: Come and Get It): could not convert string to float: 'Drama'
# Error inserting row 276 (Title: Dodsworth): could not convert string to float: 'Drama'
# Error inserting row 277 (Title: Follow the Fleet): could not convert string to float: 'Comedy'
# Error inserting row 278 (Title: Flash Gordon): could not convert string to float: 'Action'
# Error inserting row 279 (Title: Fury): could not convert string to float: 'Crime'
# Error inserting row 280 (Title: Sisters of the Gion): could not convert string to float: 'Drama'
# Error inserting row 281 (Title: The Garden of Allah): could not convert string to float: 'Adventure'
# Error inserting row 282 (Title: The Great Ziegfeld): could not convert string to float: 'Biography'
# Error inserting row 283 (Title: The Green Pastures): could not convert string to float: 'Drama'
# Error inserting row 284 (Title: The Invisible Ray): could not convert string to float: 'Horror'
# Error inserting row 285 (Title: Lloyd's of London): could not convert string to float: 'Drama'
# Error inserting row 286 (Title: Mary of Scotland): could not convert string to float: 'Biography'
# Error inserting row 287 (Title: Modern Times): could not convert string to float: 'Comedy'
# Error inserting row 288 (Title: Mayerling): could not convert string to float: 'Drama'
# Error inserting row 289 (Title: Mr. Deeds Goes to Town): could not convert string to float: 'Comedy'
# Error inserting row 290 (Title: My Man Godfrey): could not convert string to float: 'Romance'
# Error inserting row 291 (Title: Popeye the Sailor Meets Sindbad the Sailor): could not convert string to float: 'Animation'
# Error inserting row 292 (Title: The Prisoner of Shark Island): could not convert string to float: 'Biography'
# Error inserting row 293 (Title: Rembrandt): could not convert string to float: 'Biography'
# Error inserting row 294 (Title: The Story of a Cheat): could not convert string to float: 'Comedy'
# Error inserting row 295 (Title: Romeo and Juliet): could not convert string to float: 'Drama'
# Error inserting row 296 (Title: Final Accord): could not convert string to float: 'Music'
# Error inserting row 297 (Title: Secret Agent): could not convert string to float: 'Mystery'
# Error inserting row 298 (Title: Show Boat): could not convert string to float: 'Comedy'
# Error inserting row 299 (Title: San Francisco): could not convert string to float: 'Drama'
# Error inserting row 300 (Title: The Story of Louis Pasteur): could not convert string to float: 'Biography'
# Error inserting row 301 (Title: Swing Time): could not convert string to float: 'Comedy'
# Error inserting row 302 (Title: These Three): could not convert string to float: 'Drama'
# Error inserting row 303 (Title: Theodora Goes Wild): could not convert string to float: 'Comedy'
# Error inserting row 304 (Title: Three Smart Girls): could not convert string to float: 'Comedy'
# Error inserting row 305 (Title: The Trail of the Lonesome Pine): could not convert string to float: 'Drama'
# Error inserting row 306 (Title: Tsirk): could not convert string to float: 'Comedy'
# Error inserting row 307 (Title: A Day in the Country): could not convert string to float: 'Short'
# Error inserting row 308 (Title: The Awful Truth): could not convert string to float: 'Comedy'
# Error inserting row 309 (Title: Camille): could not convert string to float: 'Drama'
# Error inserting row 310 (Title: Captains Courageous): could not convert string to float: 'Adventure'
# Error inserting row 311 (Title: A Damsel in Distress): could not convert string to float: 'Comedy'
# Error inserting row 312 (Title: Daughter of Shanghai): could not convert string to float: 'Crime'
# Error inserting row 313 (Title: Elephant Boy): could not convert string to float: 'Adventure'
# Error inserting row 314 (Title: The Edge of the World): could not convert string to float: 'Drama'
# Error inserting row 315 (Title: La Grande Illusion): could not convert string to float: 'Drama'
# Error inserting row 316 (Title: The Good Earth): could not convert string to float: 'Drama'
# Error inserting row 317 (Title: The Hurricane): could not convert string to float: 'Action'
# Error inserting row 318 (Title: In Old Chicago): could not convert string to float: 'Action'
# Error inserting row 319 (Title: King Solomon's Mines): could not convert string to float: 'Action'
# Error inserting row 320 (Title: Kid Galahad): could not convert string to float: 'Crime'
# Error inserting row 321 (Title: The Life of Emile Zola): could not convert string to float: 'Biography'
# Error inserting row 322 (Title: Lost Horizon): could not convert string to float: 'Adventure'
# Error inserting row 323 (Title: Make Way for Tomorrow): could not convert string to float: 'Drama'
# Error inserting row 324 (Title: The Man Who Could Work Miracles): could not convert string to float: 'Comedy'
# Error inserting row 325 (Title: Marked Woman): could not convert string to float: 'Crime'
# Error inserting row 326 (Title: Night Must Fall): could not convert string to float: 'Drama'
# Error inserting row 327 (Title: One Hundred Men and a Girl): could not convert string to float: 'Comedy'
# Error inserting row 328 (Title: The Pearls of the Crown): could not convert string to float: 'Comedy'
# Error inserting row 329 (Title: The Prince and the Pauper): could not convert string to float: 'Adventure'
# Error inserting row 330 (Title: The Prisoner of Zenda): could not convert string to float: 'Adventure'
# Error inserting row 331 (Title: Pèpè le Moko): could not convert string to float: 'Crime'
# Error inserting row 332 (Title: Shall We Dance): could not convert string to float: 'Comedy'
# Error inserting row 333 (Title: Snow White and the Seven Dwarfs): could not convert string to float: 'Animation'
# Error inserting row 334 (Title: Stage Door): could not convert string to float: 'Comedy'
# Error inserting row 335 (Title: The Spanish Earth): could not convert string to float: 'Documentary'
# Error inserting row 336 (Title: A Star Is Born): could not convert string to float: 'Drama'
# Error inserting row 337 (Title: They Won't Forget): could not convert string to float: 'Drama'
# Error inserting row 338 (Title: This Is My Affair): could not convert string to float: 'Crime'
# Error inserting row 339 (Title: Dance Program): could not convert string to float: 'Drama'
# Error inserting row 340 (Title: Waikiki Wedding): could not convert string to float: 'Comedy'
# Error inserting row 341 (Title: Der zerbrochene Krug): could not convert string to float: 'Comedy'
# Error inserting row 342 (Title: To New Shores): could not convert string to float: 'Drama'
# Error inserting row 343 (Title: The Adventures of Robin Hood): could not convert string to float: 'Action'
# Error inserting row 344 (Title: Alexander Nevsky): could not convert string to float: 'Action'
# Error inserting row 345 (Title: The Adventures of Tom Sawyer): could not convert string to float: 'Family'
# Error inserting row 346 (Title: Algiers): could not convert string to float: 'Drama'
# Error inserting row 347 (Title: Angels with Dirty Faces): could not convert string to float: 'Crime'
# Error inserting row 348 (Title: Alexander's Ragtime Band): could not convert string to float: 'Drama'
# Error inserting row 349 (Title: The Big Broadcast of 1938): could not convert string to float: 'Animation'
# Error inserting row 350 (Title: Bringing Up Baby): could not convert string to float: 'Comedy'
# Error inserting row 351 (Title: Boys Town): could not convert string to float: 'Biography'
# Error inserting row 352 (Title: La Bète Humaine): could not convert string to float: 'Crime'
# Error inserting row 353 (Title: Carefree): could not convert string to float: 'Comedy'
# Error inserting row 354 (Title: The Citadel): could not convert string to float: 'Drama'
# Error inserting row 355 (Title: The Cowboy and the Lady): could not convert string to float: 'Comedy'
# Error inserting row 356 (Title: The Childhood of Maxim Gorky): could not convert string to float: 'Biography'
# Error inserting row 357 (Title: Drums): could not convert string to float: 'Adventure'
# Error inserting row 358 (Title: The Baker's Wife): could not convert string to float: 'Comedy'
# Error inserting row 359 (Title: Four Daughters): could not convert string to float: 'Drama'
# Error inserting row 360 (Title: The Great Waltz): could not convert string to float: 'Biography'
# Error inserting row 361 (Title: Hotel du Nord): could not convert string to float: 'Drama'
# Error inserting row 362 (Title: Jezebel): could not convert string to float: 'Drama'
# Error inserting row 363 (Title: A Woman's Face): could not convert string to float: 'Drama'
# Error inserting row 364 (Title: The Lady Vanishes): could not convert string to float: 'Comedy'
# Error inserting row 365 (Title: Love Finds Andy Hardy): could not convert string to float: 'Comedy'
# Error inserting row 366 (Title: A Man to Remember): could not convert string to float: 'Drama'
# Error inserting row 367 (Title: Marie Antoinette): could not convert string to float: 'Biography'
# Error inserting row 368 (Title: Olympia Part One: Festival of the Nations): could not convert string to float: 'Documentary'
# Error inserting row 369 (Title: Olympia Part Two: Festival of Beauty): could not convert string to float: 'Documentary'
# Error inserting row 370 (Title: Of Human Hearts): could not convert string to float: 'Drama'
# Error inserting row 371 (Title: Pygmalion): could not convert string to float: 'Comedy'
# Error inserting row 372 (Title: Port of Shadows): could not convert string to float: 'Crime'
# Error inserting row 373 (Title: The Rage of Paris): could not convert string to float: 'Comedy'
# Error inserting row 374 (Title: Sweethearts): could not convert string to float: 'Musical'
# Error inserting row 375 (Title: Test Pilot): could not convert string to float: 'Drama'
# Error inserting row 376 (Title: Three Comrades): could not convert string to float: 'Drama'
# Error inserting row 377 (Title: Too Much Johnson): could not convert string to float: 'Comedy'
# Error inserting row 378 (Title: The Beachcomber): could not convert string to float: 'Drama'
# Error inserting row 379 (Title: Volga - Volga): could not convert string to float: 'Comedy'
# Error inserting row 380 (Title: White Banners): could not convert string to float: 'Drama'
# Error inserting row 381 (Title: You Can't Take It With You): could not convert string to float: 'Comedy'
# Error inserting row 382 (Title: You and Me): could not convert string to float: 'Crime'
# Error inserting row 383 (Title: Vivacious Lady): could not convert string to float: 'Comedy'
# Error inserting row 384 (Title: Confessions of a Nazi Spy): could not convert string to float: 'Drama'
# Error inserting row 385 (Title: Dark Victory): could not convert string to float: 'Drama'
# Error inserting row 386 (Title: Destry Rides Again): could not convert string to float: 'Comedy'
# Error inserting row 387 (Title: La fin du jour): could not convert string to float: 'Drama'
# Error inserting row 388 (Title: The Four Feathers): could not convert string to float: 'Adventure'
# Error inserting row 389 (Title: Goodbye, Mr. Chips): could not convert string to float: 'Drama'
# Error inserting row 390 (Title: Gone with the Wind): could not convert string to float: 'Drama'
# Error inserting row 391 (Title: Gunga Din): could not convert string to float: 'Adventure'
# Error inserting row 392 (Title: Le Jour se Leve): could not convert string to float: 'Crime'
# Error inserting row 393 (Title: Midnight): could not convert string to float: 'Comedy'
# Error inserting row 394 (Title: The Mikado): could not convert string to float: 'Musical'
# Error inserting row 395 (Title: Mr. Smith Goes to Washington): could not convert string to float: 'Drama'
# Error inserting row 396 (Title: Ninotchka): could not convert string to float: 'Comedy'
# Error inserting row 397 (Title: Of Mice and Men): could not convert string to float: 'Drama'
# Error inserting row 398 (Title: The Rains Came): could not convert string to float: 'Adventure'
# Error inserting row 399 (Title: The Roaring Twenties): could not convert string to float: 'Crime'
# Error inserting row 400 (Title: The Rules of the Game): could not convert string to float: 'Comedy'
# Error inserting row 401 (Title: Stagecoach): could not convert string to float: 'Adventure'
# Error inserting row 402 (Title: The Stars Look Down): could not convert string to float: 'Drama'
# Error inserting row 403 (Title: The Spy in Black): could not convert string to float: 'Thriller'
# Error inserting row 404 (Title: The Story of Vernon and Irene Castle): could not convert string to float: 'Biography'
# Error inserting row 405 (Title: Tevya): could not convert string to float: 'Drama'
# Error inserting row 406 (Title: Union Pacific): could not convert string to float: 'Drama'
# Error inserting row 407 (Title: The Wizard of Oz): could not convert string to float: 'Adventure'
# Error inserting row 408 (Title: The Women): could not convert string to float: 'Comedy'
# Error inserting row 409 (Title: Wuthering Heights): could not convert string to float: 'Drama'
# Error inserting row 410 (Title: Zangiku monogatari): could not convert string to float: 'Drama'
# Error inserting row 411 (Title: Young Mr. Lincoln): could not convert string to float: 'Biography'
# Error inserting row 412 (Title: Arise, My Love): could not convert string to float: 'Comedy'
# Error inserting row 413 (Title: The Bank Dick): could not convert string to float: 'Comedy'
# Error inserting row 414 (Title: The Biscuit Eater): could not convert string to float: 'Drama'
# Error inserting row 415 (Title: Black Friday): could not convert string to float: 'Drama'
# Error inserting row 416 (Title: Dance, Girl, Dance): could not convert string to float: 'Comedy'
# Error inserting row 417 (Title: Dots): could not convert string to float: 'Short'
# Error inserting row 418 (Title: Down Argentine Way): could not convert string to float: 'Comedy'
# Error inserting row 419 (Title: Fantasia): could not convert string to float: 'Animation'
# Error inserting row 420 (Title: Foreign Correspondent): could not convert string to float: 'Romance'
# Error inserting row 421 (Title: The Grapes of Wrath): could not convert string to float: 'Drama'
# Error inserting row 422 (Title: The Great Dictator): could not convert string to float: 'Comedy'
# Error inserting row 423 (Title: His Girl Friday): could not convert string to float: 'Comedy'
# Error inserting row 424 (Title: Jud Sèè): could not convert string to float: 'Drama'
# Error inserting row 425 (Title: Kitty Foyle): could not convert string to float: 'Drama'
# Error inserting row 426 (Title: Knute Rockne All American): could not convert string to float: 'Biography'
# Error inserting row 427 (Title: The Letter): could not convert string to float: 'Crime'
# Error inserting row 428 (Title: The Long Voyage Home): could not convert string to float: 'Drama'
# Error inserting row 429 (Title: The Mark of Zorro): could not convert string to float: 'Action'
# Error inserting row 430 (Title: Night Train to Munich): could not convert string to float: 'Comedy'
# Error inserting row 431 (Title: North West Mounted Police): could not convert string to float: 'Action'
# Error inserting row 432 (Title: Our Town): could not convert string to float: 'Drama'
# Error inserting row 433 (Title: The Philadelphia Story): could not convert string to float: 'Comedy'
# Error inserting row 434 (Title: Pinocchio): could not convert string to float: 'Animation'
# Error inserting row 435 (Title: Rebecca): could not convert string to float: 'Mystery'
# Error inserting row 436 (Title: The Shop Around the Corner): could not convert string to float: 'Comedy'
# Error inserting row 437 (Title: Strike Up the Band): could not convert string to float: 'Comedy'
# Error inserting row 438 (Title: The Thief of Bagdad): could not convert string to float: 'Adventure'
# Error inserting row 439 (Title: The Westerner): could not convert string to float: 'Drama'
# Error inserting row 440 (Title: Blood and Sand): could not convert string to float: 'Drama'
# Error inserting row 441 (Title: The Blood of Jesus): could not convert string to float: 'Drama'
# Error inserting row 442 (Title: Blossoms in the Dust): could not convert string to float: 'Biography'
# Error inserting row 443 (Title: Citizen Kane): could not convert string to float: 'Drama'
# Error inserting row 444 (Title: The Devil and Daniel Webster): could not convert string to float: 'Comedy'
# Error inserting row 445 (Title: Dumbo): could not convert string to float: 'Animation'
# Error inserting row 446 (Title: The Well-Digger's Daughter): could not convert string to float: 'Comedy'
# Error inserting row 447 (Title: 49th Parallel): could not convert string to float: 'Drama'
# Error inserting row 448 (Title: Here Comes Mr. Jordan): could not convert string to float: 'Fantasy'
# Error inserting row 449 (Title: High Sierra): could not convert string to float: 'Adventure'
# Error inserting row 450 (Title: How Green Was My Valley): could not convert string to float: 'Drama'
# Error inserting row 451 (Title: Hold Back the Dawn): could not convert string to float: 'Drama'
# Error inserting row 452 (Title: The Land): could not convert string to float: 'Documentary'
# Error inserting row 453 (Title: The Little Foxes): could not convert string to float: 'Drama'
# Error inserting row 454 (Title: The Lady Eve): could not convert string to float: 'Comedy'
# Error inserting row 455 (Title: The Maltese Falcon): could not convert string to float: 'Crime'
# Error inserting row 456 (Title: Love on the Dole): could not convert string to float: 'Drama'
# Error inserting row 457 (Title: Major Barbara): could not convert string to float: 'Comedy'
# Error inserting row 458 (Title: The Man Who Came to Dinner): could not convert string to float: 'Comedy'
# Error inserting row 459 (Title: Penny Serenade): could not convert string to float: 'Drama'
# Error inserting row 460 (Title: 'Pimpernel' Smith): could not convert string to float: 'Adventure'
# Error inserting row 461 (Title: Road to Zanzibar): could not convert string to float: 'Adventure'
# Error inserting row 462 (Title: The Sea Wolf): could not convert string to float: 'Drama'
# Error inserting row 463 (Title: Sergeant York): could not convert string to float: 'Biography'
# Error inserting row 464 (Title: Sullivan's Travels): could not convert string to float: 'Adventure'
# Error inserting row 465 (Title: Suspicion): could not convert string to float: 'Mystery'
# Error inserting row 466 (Title: That Hamilton Woman): could not convert string to float: 'Drama'
# Error inserting row 467 (Title: Tom Dick and Harry): could not convert string to float: 'Comedy'
# Error inserting row 468 (Title: The Brothers and Sisters of the Toda Family): could not convert string to float: 'Drama'
# Error inserting row 469 (Title: Two-Faced Woman): could not convert string to float: 'Comedy'
# Error inserting row 470 (Title: The Wolf Man): could not convert string to float: 'Drama'
# Error inserting row 471 (Title: Across the Pacific): could not convert string to float: 'Action'
# Error inserting row 472 (Title: Bambi): could not convert string to float: 'Animation'
# Error inserting row 473 (Title: The Black Swan): could not convert string to float: 'Action'
# Error inserting row 474 (Title: Casablanca): could not convert string to float: 'Drama'
# Error inserting row 475 (Title: Cat People): could not convert string to float: 'Horror'
# Error inserting row 476 (Title: People on the Alps): could not convert string to float: 'Drama'
# Error inserting row 477 (Title: Der groèe Kènig): could not convert string to float: 'Drama'
# Error inserting row 478 (Title: The Hard Way): could not convert string to float: 'Drama'
# Error inserting row 479 (Title: Holiday Inn): could not convert string to float: 'Comedy'
# Error inserting row 480 (Title: In Which We Serve): could not convert string to float: 'Drama'
# Error inserting row 481 (Title: Jungle Book): could not convert string to float: 'Action'
# Error inserting row 482 (Title: Journey for Margaret): could not convert string to float: 'Drama'
# Error inserting row 483 (Title: The Magnificent Ambersons): could not convert string to float: 'Drama'
# Error inserting row 484 (Title: The Male Animal): could not convert string to float: 'Comedy'
# Error inserting row 485 (Title: The Major and the Minor): could not convert string to float: 'Comedy'
# Error inserting row 486 (Title: The Moon and Sixpence): could not convert string to float: 'Drama'
# Error inserting row 487 (Title: Mrs. Miniver): could not convert string to float: 'Drama'
# Error inserting row 488 (Title: Native Land): could not convert string to float: 'Drama'
# Error inserting row 489 (Title: My Gal Sal): could not convert string to float: 'Biography'
# Error inserting row 490 (Title: Now, Voyager): could not convert string to float: 'Drama'
# Error inserting row 491 (Title: Ossessione): could not convert string to float: 'Crime'
# Error inserting row 492 (Title: One of Our Aircraft Is Missing): could not convert string to float: 'Action'
# Error inserting row 493 (Title: The Pied Piper): could not convert string to float: 'Drama'
# Error inserting row 494 (Title: Prelude to War): could not convert string to float: 'Documentary'
# Error inserting row 495 (Title: The Pride of the Yankees): could not convert string to float: 'Biography'
# Error inserting row 496 (Title: Random Harvest): could not convert string to float: 'Drama'
# Error inserting row 497 (Title: Reap the Wild Wind): could not convert string to float: 'Action'
# Error inserting row 498 (Title: Road to Morocco): could not convert string to float: 'Adventure'
# Error inserting row 499 (Title: Saboteur): could not convert string to float: 'Thriller'
# Error inserting row 500 (Title: Kate & Leopold): could not convert string to float: 'Comedy'
# Error inserting row 501 (Title: Thunder Rock): could not convert string to float: 'Drama'
# Error inserting row 502 (Title: This Above All): could not convert string to float: 'Drama'
# Error inserting row 503 (Title: To Be or Not to Be): could not convert string to float: 'Comedy'
# Error inserting row 504 (Title: Wake Island): could not convert string to float: 'Action'
# Error inserting row 505 (Title: Woman of the Year): could not convert string to float: 'Comedy'
# ...
#
# Error inserting row 23319 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23320 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23321 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23322 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23323 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23324 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23325 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23326 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23327 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23328 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23329 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23330 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23331 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23332 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23333 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23334 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23335 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23336 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23337 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23338 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23339 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23340 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23341 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23342 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23343 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23344 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23345 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23346 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23347 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23348 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23349 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23350 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23351 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23352 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23353 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23354 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23355 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23356 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23357 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23358 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23359 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23360 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23361 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23362 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23363 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23364 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23365 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23366 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23367 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23368 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23369 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23370 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23371 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23372 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23373 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23374 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23375 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23376 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23377 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23378 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23379 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23380 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23381 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23382 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23383 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23384 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23385 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23386 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23387 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23388 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23389 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23390 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23391 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23392 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23393 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23394 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23395 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23396 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23397 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23398 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23399 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23400 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23401 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23402 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23403 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23404 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23405 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23406 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23407 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23408 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23409 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23410 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23411 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23412 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23413 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23414 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23415 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23416 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23417 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23418 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23419 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23420 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23421 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23422 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23423 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23424 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23425 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23426 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23427 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23428 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23429 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23430 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23431 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23432 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23433 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23434 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23435 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23436 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23437 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23438 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23439 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23440 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23441 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23442 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23443 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23444 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23445 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Error inserting row 23446 (Title: -): ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
# Data inserted successfully!

# %%
conn.rollback()

# %%
df.to_parquet('database_movies.parquet', index=False)
